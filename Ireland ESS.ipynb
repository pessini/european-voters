# %%
import pandas as pd
import numpy as np

# %%
ireland = pd.read_spss('./ESS9csIE.sav')

# %%
ireland.head()
# Out:
#    idno cntry                                             x1  \
# 0  15.0    IE  My skills are higher than I need to do my job
# 1  39.0    IE                                            NaN
# 2  68.0    IE  My skills are higher than I need to do my job
# 3  71.0    IE                                            NaN
# 4  79.0    IE                                            NaN
#
#                                                   x2  \
# 0  Junior Certificate; NFQ Level 3 (including Tra...
# 1                                                NaN
# 2  Leaving Certificate Established (LCE); Leaving...
# 3                                                NaN
# 4                                                NaN
#
#                       x3t4_1                  x3t4_2             x5      x6  \
# 0                          5                       4  A little true  2012.0
# 1     10 Extremely important  10 Extremely important            NaN     NaN
# ...

# %%
ireland.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2216 entries, 0 to 2215
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   idno     2216 non-null   float64
#  1   cntry    2216 non-null   object
#  2   x1       1051 non-null   category
#  3   x2       1033 non-null   category
#  4   x3t4_1   2200 non-null   category
#  5   x3t4_2   2197 non-null   category
#  6   x5       1043 non-null   category
#  7   x6       1003 non-null   float64
#  8   x7       1898 non-null   category
#  9   x7other  2216 non-null   object
#  10  x8       1854 non-null   category
#  11  x9       1936 non-null   category
#  12  prtvie1  1410 non-null   category
#  13  prtvie2  1273 non-null   category
# dtypes: category(10), float64(2), object(2)
# memory usage: 94.1+ KB

# %%
ireland_general = pd.read_spss('./ESS9IE.sav')

# %%
ireland_general.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2216 entries, 0 to 2215
# Columns: 572 entries, name to psu
# dtypes: category(558), float64(11), object(3)
# memory usage: 1.7+ MB

# %%
ireland_general.head()
# Out:
#         name  essround edition    proddate  idno    cntry nwspol   netusoft  \
# 0  ESS9e03_1       9.0     3.1  17.02.2021  15.0  Ireland   20.0  Every day
# 1  ESS9e03_1       9.0     3.1  17.02.2021  39.0  Ireland   30.0  Every day
# 2  ESS9e03_1       9.0     3.1  17.02.2021  68.0  Ireland    0.0  Every day
# 3  ESS9e03_1       9.0     3.1  17.02.2021  71.0  Ireland  120.0      Never
# 4  ESS9e03_1       9.0     3.1  17.02.2021  79.0  Ireland  240.0      Never
#
#   netustm ppltrst  ... inwemm inwtm   dweight   pspwght   pweight  anweight  \
# 0    60.0       5  ...   39.0  51.0  0.922627  1.507023  0.172561  0.260053
# 1   360.0       3  ...   51.0  42.0  1.845254  3.014047  0.172561  0.520106
# 2   120.0       5  ...   36.0  51.0  0.922627  0.776709  0.172561  0.134029
# 3     NaN       3  ...   40.0  59.0  0.461313  0.264468  0.172561  0.045637
# 4     NaN       9  ...   21.0  76.0  0.922627  0.623755  0.172561  0.107635
#
#   domain      prob stratum      psu
# ...

# %%
ireland_general.vteurmmb.isnull().sum()
# Out:
# 85

# %%
variables = ["cntry", 
               "eduyrs", 
               "eisced",
               "uemp3m", 
               "mbtru", 
               "vteurmmb", 
               "yrbrn", 
               "agea", 
               "gndr", 
               "anweight", 
               "psu", 
               "stratum"]

# %%
df_clean = ireland_general.loc[:,variables]

# %%
df_clean.head()
# Out:
#      cntry eduyrs                                        eisced uemp3m  \
# 0  Ireland   19.0  ES-ISCED IV, advanced vocational, sub-degree     No
# 1  Ireland   16.0  ES-ISCED IV, advanced vocational, sub-degree    Yes
# 2  Ireland   15.0  ES-ISCED IV, advanced vocational, sub-degree     No
# 3  Ireland    7.0        ES-ISCED I , less than lower secondary     No
# 4  Ireland   20.0  ES-ISCED IV, advanced vocational, sub-degree     No
#
#              mbtru                             vteurmmb   yrbrn  agea    gndr  \
# 0  Yes, previously  Remain member of the European Union  1984.0  34.0    Male
# 1               No  Remain member of the European Union  1996.0  23.0    Male
# 2               No  Remain member of the European Union  1984.0  35.0  Female
# 3               No  Remain member of the European Union  1951.0  68.0    Male
# 4  Yes, previously  Remain member of the European Union  1940.0  79.0  Female
#
#    anweight      psu  stratum
# 0  0.260053  14244.0   1885.0
# ...

# %%
df_clean.groupby('vteurmmb').size()
# Out:
# vteurmmb
# Leave the European Union                125
# Not eligible to vote                     48
# Remain member of the European Union    1914
# Would not vote                           38
# Would spoil the ballot paper              2
# Would submit a blank ballot paper         4
# dtype: int64

# %%
italy = pd.read_spss('./ESS9IT.sav')
it_clean = italy.loc[:,variables]
it_clean.head()
# Out:
#    cntry eduyrs                                           eisced uemp3m mbtru  \
# 0  Italy   13.0        ES-ISCED IIIa, upper tier upper secondary    Yes    No
# 1  Italy   10.0                     ES-ISCED II, lower secondary    Yes    No
# 2  Italy   15.0  ES-ISCED V1, lower tertiary education, BA level     No    No
# 3  Italy   20.0  ES-ISCED V1, lower tertiary education, BA level    Yes    No
# 4  Italy    8.0                     ES-ISCED II, lower secondary    Yes    No
#
#                               vteurmmb   yrbrn  agea    gndr  anweight  \
# 0  Remain member of the European Union  1981.0  38.0  Female  1.765664
# 1                 Not eligible to vote  2002.0  17.0    Male  1.822796
# 2  Remain member of the European Union  1991.0  28.0    Male  1.558781
# 3  Remain member of the European Union  1990.0  29.0  Female  1.883601
# 4             Leave the European Union  1974.0  45.0    Male  2.741621
#
#        psu  stratum
# 0  15837.0   2403.0
# 1  15862.0   2422.0
# ...

# %%
it_clean.groupby('vteurmmb').size()
# Out:
# vteurmmb
# Leave the European Union                438
# Not eligible to vote                     53
# Remain member of the European Union    1679
# Would not vote                          150
# Would spoil the ballot paper             13
# Would submit a blank ballot paper        54
# dtype: int64
